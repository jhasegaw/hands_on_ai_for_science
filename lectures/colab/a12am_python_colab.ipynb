# %% [markdown]
# # Hands-On AI for Science
# ## August 12, Morning: Python `if` statements

# %% [markdown]
# ### Self-contained Colab notebook
#
# Everything you need is in this notebook — there is nothing to install and nothing to download. Just run the cells in order.

# %% [markdown]
# In this lecture, you will begin programming in python.

# %% [markdown]
# 1. [Setting up Python, and Downloading these lecture notes](#section1)
# 2. [Strings](#strings)
# 3. [Numbers](#numbers)
# 4. [If statements](#ifstatements)
# 5. [Functions and Modules](#functions)
# 6. [Homework](#homework)

# %% [markdown]
# <a id="section1"></a>

# %% [markdown]
# ## 1. Setting up Python, Anaconda, and Jupyter Notebook

# %% [markdown]
# ### 1.1 Installing Anaconda
#
# The very first thing you should do is to install python.  If you have never used python before, I recommend installing it from https://anaconda.com.  That will install many packages that you need including Jupyter (https://docs.jupyter.org/) and numpy (https://numpy.org/).
#
# Just go to the anaconda web page (https://www.anaconda.com/), click the **Download** button.  Once you have downloaded the installer, click on it, and follow the instructions to install it.

# %% [markdown]
# ### 1.2 Downloading these lecture notes

# %% [markdown]
# This course is going to work best if you can follow along in your own computer, so let's download the lecture notes.
#
# If you can't get `git` to work, then you can just download these notes by going to https://github.com/jhasegaw/hands_on_ai_for_science/tree/main/lectures, and downloading all of the individual files there, or we could try distributing the files on Box.  However, it's probably easier to use `git`.  Here are instructions that should work:
#
# ### If you're on a Mac:
#
# 1. Use the search bar to search for `Terminal`, and open it.
# 2. Type `git --version` and press Enter.
# 3. A pop-up dialog box will appear stating: "The 'git' command requires the command line developer tools." Click `Install` to automatically download and configure Apple's Xcode Command Line Tools, which includes Git.
# 4. In your terminal, type the following command to download all of the lecture notes:
# ```
# git clone https://github.com/jhasegaw/hands_on_ai_for_science
# cd hands_on_ai_for_science/lectures
# ```
#
# ### If you're on Windows:
#
# 1. Press the Windows key on your keyboard
# 2. Type `Powershell` to start powershell.
# 3. In powershell, type `winget install Git.Git` to install git.
# 4. Now get the lecture notes by typing:
#
# ```
# git clone https://github.com/jhasegaw/hands_on_ai_for_science
# chdir hands_on_ai_for_science\lectures
# ```

# %% [markdown]
# ### 1.3 Using the Jupyter Notebook
#
# The lecture notes for this course are distributed in the form of Jupyter notebooks.
#
# A **Jupyter notebook** is an interactive python programming session that runs in your web browser.  There is a python interpreter running in the background, that interprets all of your commands, and prints the results.

# %% [markdown]
# A Jupyter notebook is a file that ends in the extension `.ipynb`.  In some environments, you might be able to just double-click on such a file, but that has never worked for me.  Instead, once you have anaconda installed, and you've changed into the directory with the lecture notes, you should be able to just type:
#
# `jupyter notebook`
#
# That should automatically cause the Jupyter browswer to start running in a window on your web browser.  In the browser, click on the notebook you want to read.  For example, this one is called `a12am_python.ipynb`.

# %% [markdown]
# A Jupyter notebook has two main types of windows:
#
# 1. **Markdown** windows are like this one.  They contain text, which is formatted using a very simple formatting language called markdown.  Find more information about markdown here: https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd.
#
# If you double-click on a markdown window, the text will convert from **formatted** to **unformatted**, and then you can edit it.   Hit `shift-return` (hit the return key while holding the shift key) in order to return to **formatted** text.
#
#
# 2. **Code** windows contain python code.
#
# The window immediately after this one is a `code` window.  Notice how its background is gray, instead of white.
#
# Copy the text `print("Hello world")` into the next window, then hit `shift-return`.  You should see the text `Hello world` printed, in response, just below the window.

# %% [markdown]
# ### 1.3 Arithmetic in Python
#
# Python makes a great desktop calculator.  For example:

# %%
7*123

# %% [markdown]
# <a id="strings"></a>

# %% [markdown]
# ## 2 Strings
#
# A string is a sequence of characters inside quotes.  For example:

# %%
name1 = "Urbana"
name2 = "Illinois"

# %% [markdown]
# You can print the content of a string:

# %%
print(name1)

# %% [markdown]
# Or you can print its type:

# %%
print(type(name1))

# %% [markdown]
# The `+` sign concatenates strings.  The `*` sign repeats a string:

# %%
print(name1 + " is in " + name2*3 )

# %% [markdown]
# <a id="numbers"></a>

# %% [markdown]
# ## 3. Numbers
#
# Most numbers are called `floats`, or `floating point numbers`.  They are used to do calculations:

# %%
x = -17.89

y = 5/3

print(x, " is less than ", y)

# %%
print(type(y))

# %%
print(round(y))

# %% [markdown]
# You can convert a float into a string, if you want to use the string versions of `+` and `*` instead of the numerical meanings:

# %%
print("17.89*5 is ", 17.89*5, " but str(17.89)*5 is ", str(17.89)*5)

# %% [markdown]
# Integers are used for indexing.  They are numerical objects, but unlike floats, they don't have any fractional part.

# %%
a = 7
b = -23
c = 0
print(type(b))

# %% [markdown]
# If you divide two integers, you usually get a float.

# %%
print(b/a, " is of type", type(b/a))

# %% [markdown]
# If you want just the integer part of the division, use `//` instead.

# %%
print(b//a, " is of type ", type(b//a))

# %% [markdown]
# If you convert a float to int, it will truncate the fractional part:

# %%
x = - 17.89
y = 5/3
xx = int(x)
yy = int(y)
print(x, xx, y, yy)

# %% [markdown]
# <a id="ifstatements"></a>

# %% [markdown]
# ## 4 "If" statements
#
# In python, the "if" statement works like this:
# * 'if', then the condition, then a colon
# * The next line MUST START WITH AN INDENT!
# * The first line with an indent is the end of the if statement

# %%
x=3
if x==3:
    print('It worked')

# %% [markdown]
# You can check many different possibilities by using `if`, then `elif`, then `else`, as follows:

# %%
x=3

if x>3:
    print("x is greater than 3!")
elif x==3:
    print("x is equal to 3!")
else:
    print("x is less than 3!")

# %% [markdown]
# <a id="functions"></a>

# %% [markdown]
# ## 5 Functions and modules

# %% [markdown]
# In python, a function is defined as follows:
# * `def`, then the function name and arguments, then a colon
# * The next line must be indented!
# * The first line without an indent ends the function
# * Use the `return` statement if you want the function to return something
# * When you want to call the function, just type its name

# %%
def doubleme(x):
    return 2*x

print('doubleme(4) is', doubleme(4))
print('doubleme(5) is', doubleme(5))
print('doubleme(6) is', doubleme(6))

# %% [markdown]
# A **module** in python is an external file that contains some code you want to run.  **Python is useful primarily because so many people have written so many amazing modules.** You can run their code by just downloading it, and importing it using the `import` command.
#
# * The `import` command runs the code in a file
# * The file can be one in the same directory (a file you wrote) **or** it can be a module that's distributed with python. Some of the modules you can import are listed [here](https://docs.python.org/3/library/index.html).
#
# For example, `math` is a module that comes with python.  We can import it using `import math`, then, **after we import it**, we can use the `help` command to find out what's inside it.

# %%
import math
help(math.sqrt)

# %% [markdown]
# **WARNING:** The same idea applies to code you write in this notebook.
#
# 1. Run a cell that defines a function
# 2. Edit the function to change some stuff
# 3. Use the function again
#
# Python is still using the **old** version until you re-run the cell that defines it!  Whenever you edit a function, re-run its cell (Shift+Enter) before testing it again.
#
# (In the downloadable version of this course the functions live in a separate `.py` file, and you reload them with `importlib.reload`.  In this self-contained notebook, re-running the cell does the same job.)

# %% [markdown]
# <a id="loops"></a>

# %% [markdown]
# <a id="homework"></a>

# %% [markdown]
# ## Homework

# %% [markdown]
# For each of the lectures, we will have a short `homework assignment` that you can do to test what you've learned.  Each homework assignment will usually ask you to fill out the code for one or two functions.  Note: We are not grading you on this!  Therefore, you should use these assignments in whatever way will best help you to learn. If you want to try solving it from scratch, please do so.  If you want to ask a friend, a friendly AI, or a friendly instructor for help, please do so.
#
# You can get information about the homework by importing it, and then typing `help` with the name of the homework.

# %% [markdown]
# ### Your code goes here: `a12am_hw1`
#
# The functions below are the ones you need to write. **Edit them right here in this cell**, then re-run this cell (Shift+Enter) to update your definitions. Re-run the cells further down to test them.

# %%
def arithmetic(x, y):
    """
    Modify this code so that it performs one of four possible functions, 
    as specified in the following table:

                        isinstance(x,str)  isinstance(x,float)
    isinstance(y,str)   return x+y         return str(x)+y
    isinstance(y,float) return x*int(y)    return x*y
    """
    raise RuntimeError("You need to write this part!")

# %%
help(arithmetic)

# %% [markdown]
# If you want to try writing this function, scroll up to the code cell holding the function definitions and edit it there.
#
# The first thing you might notice: This function, `arithmetic`, contains only one command.  It contains the command `raise RuntimeError("You need to write this part!")`.  If you try to run `arithmetic` without editing it, the `raise` command will raise an error and quit!

# %%
arithmetic(3,5)

# %% [markdown]
# 1. Obviously, the first thing you need to do is to delete the line `raise RuntimeError("You need to write this part!")`
# 2. The second thing you need to do is to add some code into the file that will do the stuff suggested by the docstring.  Once you've got it working, the following block of code should print the results
#
# ```
# arithmetic("very", "cool") is: verycool
# arithmetic(3, "times") is: 3times
# arithmetic("times", 3) is: timestimestimes
# arithmetic(2,5) is: 10
# ```

# %%
x = arithmetic("very", "cool")
print('arithmetic("very", "cool") is:', x)

y = arithmetic(3.0, "times")
print('arithmetic(3.0, "times") is:', y)

z = arithmetic("times", 3.0)
print('arithmetic("times", 3.0) is:', z)

q = arithmetic(2.0, 5.0)
print('arithmetic(2.0,5.0) is:', q)
