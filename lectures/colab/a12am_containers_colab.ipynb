# %% [markdown]
# # Hands-On AI for Science
# ## August 12, Morning: Loops, Lists, Tuples and Dictionaries

# %% [markdown]
# ### Self-contained Colab notebook
#
# Everything you need is in this notebook — there is nothing to install and nothing to download. Just run the cells in order.

# %% [markdown]
# 1. [Loops](#loops)
# 2. [Lists and Tuples](#lists)
# 3. [List comprehension](#comprehension)
# 4. [Dictionaries](#dictionaries)
# 6. [Homework](#homework)

# %% [markdown]
# <a id="loops"></a>

# %% [markdown]
# ## 1. Loops

# %% [markdown]
# A `while` loop executes its content as long as the condition is satisfied:

# %%
x = 14
while x > 6:
    print(x)
    x = x-2
print("The loop ended, and now x == ",x)

# %% [markdown]
# A `for` loop iterates through a fixed set of values.  Each time you go through the loop, the variable is set to one of the given values.  For example,

# %%
for x in [2,3,4,5,6]:
    print("x is now",x)

# %% [markdown]
# Often, you'll want to use the `for` command to iterate a fixed number of times.  In python, that's done using the `range` function.
#
# * `range(n)` generates all of the numbers starting at 0, and ending just before n
# * `range(m,n)` generates all of the numbers starting at m, and ending just before n
# * `range(m,n,p)` generates all of the numbers starting at m, and ending just before n, with a step size of p

# %%
for x in range(3):
    print(x)

# %%
for n in range(2,5):
    print(n)

# %%
for n in range(14,8,-1):
    print(n)

# %% [markdown]
# Here's something else worth knowing:  The `range` function can be replaced by any other object that specifies a sequence.  For example, if you use a string, the `for` command will iterate through the letters of the string:

# %%
for c in "abcdefg":
    print("The next letter is ",c)

# %% [markdown]
# <a id="lists"></a>

# %% [markdown]
# ## 2: Lists and Tuples
#
# `list`s and `tuple`s, in python, are sequences of objects.  The objects can be of any type.
#
# There is a special syntax for creating `list`s and `tuple`s:
# * To create a `list`, we use the symbol `[` to start the list, and the symbol `]` to end it.
# * To create a `tuple`, we use the symbol `(` to start the typle, and the symbol `)` to end it.

# %%
list1 = [ 1, 2, 3, "hello", "world", True, True, False ]
print(list1)

tuple1 = ( 1, 2, 3, "hello", "world", True, True, False )
print(tuple1)

# %% [markdown]
# You can also create lists and tuples in other ways.  For example, you can convert a string into either a list or a tuple:

# %%
string2 = "This is a string"
list2 = list(string2)
tuple2 = tuple(string2)
print(list2)
print(tuple2)
print(len(tuple2))

# %% [markdown]
# You can create an empty list or tuple using the syntax `[]` or `()`:

# %%
empty_list = []
empty_tuple = ()
print("The list ", empty_list, "has a length of", len(empty_list))
print("The tuple ", empty_tuple, "has a length of", len(empty_tuple))

# %%
print(list1[3])
print(tuple1[3])

# %% [markdown]
# If you slice a list or tuple, you get another list or tuple:

# %%
print(list1[2:5])
print(tuple1[2:5])

# %% [markdown]
# **The difference between lists and tuples:**
#
# * You can change the contents of a list
# * You cannot change the contents of a tuple, after it has been created

# %%
list1[4] = "Urbana"
print(list1)

# %%
tuple1[4] = "Urbana"
print(tuple1)

# %% [markdown]
# ### Adding and Multiplying Lists or Tuples
#
# Adding or multiplying lists or tuples is the same as adding or multiplying strings:

# %%
list1 = ['hello', 'world']
tuple1 = ('hello', 'world')

list3 = ['a', 'b', 'c']
tuple3 = ('a', 'b', 'c')

print(list1+list3)
print(tuple1 + tuple3)
print(list3*4)
print(tuple3*2)

# %% [markdown]
# ### List Methods
#
# Lists and tuples are types of objects.  Since this is object-oriented programming, each type of object has particular methods that can be called on it.
#
# * List methods are here: https://docs.python.org/3/tutorial/datastructures.html
#
# Here are a few of the most useful ones:

# %%
for x, s in enumerate(list1+list3*2):
    print(x,s)

# %%
list1 = ['hello', 'world']
list1.append("a long string to put at the end")
print(list1, "has a length of", len(list1))

empty_list = []
empty_list.append("a")
empty_list.append("b")
empty_list.append("c")
print("The formerly empty list is now", empty_list, "and has a length of", len(empty_list))

# %%
wordlist = ['hello', 'this', 'is', 'a', 'sentence']
wordlist.sort()
print(wordlist)

# %%
print("the length of list1 is", len(list1))
for n in range(len(list1)):
    print(n, list1[n])

# %% [markdown]
# <a id="comprehension"></a>

# %% [markdown]
# ## 3. List comprehension
#
# * Python has a special syntax called `list comprehension`
# * It defines a list by running a for loop inside the list!

# %%
z = [ 2*w for w in range(45, 67, 2) ]
print('2*w for w ranging from 45 to 67 with steps of 2 is:')
print(z)

# %% [markdown]
# List comprehension can include `if` statements:

# %%
z = [ 2*w for w in ['hello', 5, 7.5, 10] if isinstance(w,int) ]
print(z)

# %% [markdown]
# <a id="dictionaries"></a>

# %% [markdown]
# ## 4 Dictionaries
#
# A `dict` is like a list, except that instead of being indexed by integers, you can use almost anything as the index.
#
# * There is a special syntax to create a `dict`: you put `{` at the beginning, and `}` at the end.
# * Since the key for each element of a `dict` is up to you, you need to specify it.  This is done by writing a colon between pairs of `key` and `value`.
# * Once you have created a `dict` in this way, you can use the `key` to access the `value`.

# %%
dict1 = { 0: "this is value number #0", "some key" : 35 }
print(dict1)

#print(dict1[0])
print(dict1["some key"])

# %% [markdown]
# One of the most useful things to do with a dictionary is to iterate over its elements.  Here are the three iterators:
#
# * `.keys()` gives you an iterator over the dictionary's keys
# * `.values()` gives you an iterator over the dictionary's values
# * `.items()` gives you an iterator over (key, value) tuples

# %%
for n, k in enumerate(dict1.keys()):
    print("Key number ", n, " is ", k)

# %%
for n, k in enumerate(dict1.values()):
    print("Value number ", n, " is ", k)

# %%
for n, k in enumerate(dict1.items()):
    print("Item number ", n, " is ", k)

# %% [markdown]
# <a id="homework"></a>

# %% [markdown]
# ## Homework

# %% [markdown]
# As before, `homework` is just to give you some practice problems, so you can check whether or not you've learned how python works.  This time, the homework has two functions to write:

# %% [markdown]
# ### ✍️ Your turn: write `words2characters`, `next_birthday`
#
# **This is where you write code.**  Fill them in below, then run this cell (Shift+Enter).  The cells underneath use them, so come back and re-run this cell every time you change them.

# %%
def words2characters(words):
    """
    This function converts a list of words into a list of characters.

    @param:
    words - a list of words

    @return:
    characters - a list of characters

    Every element of "words" should be converted to a str, then split into
    characters, each of which is separately appended to "characters." For 
    example, if words==['hello', 1.234, True], then characters should be
    ['h', 'e', 'l', 'l', 'o', '1', '.', '2', '3', '4', 'T', 'r', 'u', 'e']
    """
    raise RuntimeError("You need to write this part!")

def next_birthday(date, birthdays):
    '''
    Find the next birthday after the given date.

    @param:
    date - a tuple of two integers specifying (month, day)
    birthdays - a dict mapping from date tuples to lists of names, for example,
      birthdays[(1,10)] = list of all people with birthdays on January 10.

    @return:
    birthday - the next day, after given date, on which somebody has a birthday
    list_of_names - list of all people with birthdays on that date
    '''
    raise RuntimeError("You need to write this part!")

# %%
help(words2characters)
help(next_birthday)

# %% [markdown]
# As before, you should edit the function definitions in the code cell above.  Then:
#
# 1. Delete the line that says something like `raise RuntimeError("You need to write this part!")`
# 2. Add some lines to do what the homework says it should do.
#
# In this case, the function `words2characters` is probably easier to write than `next_birthday`, so start with that one:

# %%
characters = words2characters([ "this", "is", "a" , "list", 526 ])
print('The returned list of characters is:', characters)

# %% [markdown]
# Now let's try `next_birthday`:

# %%
birthdays = {
    (2,22) : [ "Washington" ],
    (2,12) : ["Lincoln"],
    (1,15): ["Martin Luther King"],
    (4,13): ["Thomas Jefferson"]
}

print('The next birthday after March 3 is:', next_birthday((3,3), birthdays))

print('The next birthday after December 26 is:', next_birthday((12,26), birthdays))
